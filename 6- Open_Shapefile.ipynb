# %%
# Import the packages
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Read the shapefile
ds=gpd.read_file("World_Countries__Generalized_.shp")

# %%
# Here we can see the attribute table of the shapefile
ds
# Out:
#      FID                               COUNTRY ISO          COUNTRYAFF  \
# 0      1                        American Samoa  AS       United States
# 1      2  United States Minor Outlying Islands  UM       United States
# 2      3                          Cook Islands  CK         New Zealand
# 3      4                      French Polynesia  PF              France
# 4      5                                  Niue  NU         New Zealand
# ..   ...                                   ...  ..                 ...
# 244  245              Northern Mariana Islands  MP       United States
# 245  246                                 Palau  PW               Palau
# 246  247                    Russian Federation  RU  Russian Federation
# 247  248                                 Spain  ES               Spain
# 248  249                              Canarias  ES               Spain
#
#     AFF_ISO   SHAPE_Leng   SHAPE_Area  \
# 0        US     0.600124     0.013720
# ...

# %%
# Plot the shapefile
ds.plot()
# Out:
# <AxesSubplot:>

# %%
# Plot the shapefile based on the area of every country and use a color map
ds.plot(column="SHAPE_Area",cmap="OrRd")
# Out:
# <AxesSubplot:>

# %%
# Plot the shapefile based on the area of every country and use a color map with legend

fig, ax=plt.subplots(1,1)
ds.plot(column="SHAPE_Area",ax=ax,legend=True)
# Out:
# <AxesSubplot:>

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax=plt.subplots(1,1)
divider=make_axes_locatable(ax)
cax=divider.append_axes("right",size="5%",pad=0.1)
ds.plot(column='SHAPE_Area',ax=ax,legend=True,cax=cax)
# Out:
# <AxesSubplot:>
